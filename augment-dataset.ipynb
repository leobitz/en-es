# %%
# paraphrase english 10k
# paraphrase spanish 10k
# back-translation 10k
# adversarial 10k - random text
# perturbation 10k - swamp delete update
# english synonym 10k - nltk
# spanish synonym 10k - nltk
# concatenate 10k
# total 80k synthetic data

# %%
import pandas as pd
import os
from parrot import Parrot
import torch
import warnings
import random
import numpy as np
import tqdm
from transformers import pipeline
import string

# seed
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
   torch.cuda.manual_seed_all(seed)

warnings.filterwarnings("ignore")

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
df = pd.read_parquet("exp-data/en-es-train-val.parquet")

# %%
df
# Out:
#                            dataset  split  \
# 0       english-spanish-translator  train
# 1       english-spanish-translator  train
# 2            mustc-en-es-text-only  train
# 3                 OPUS-books-EN-ES  train
# 4              wikipedia_en_es_m2m  train
# ...                            ...    ...
# 109995                corpus-en-es    val
# 109996  english-spanish-translator    val
# 109997            OPUS-books-EN-ES    val
# 109998         wikipedia_en_es_m2m    val
# 109999         wikipedia_en_es_m2m    val
#
#                                                        EN  \
# 0                                       Please answer me.
# 1                                           I didn't ask.
# 2       Because after all, the people we are coupled t...
# 3       "Faith, that's true, Mr. Spilett," replied the...
# 4       Greece has many islands, with estimates rangin...
# ...                                                   ...
# 109995  We should not only be paying attention to road...
# 109996                       I can't wait to be a father.
# 109997                       "I am, then, your prisoner?"
# 109998  The cryosphere (from the Greek kryos, "cold", ...
# 109999  The following is a list of contemporary ethnic...
#
#                                                        ES  length
# 0                                  Por favor, contestame.       7
# 1                                         Yo no pregunté.       8
# 2       Porque después de todo, las personas con las q...      28
# 3       –Señor Spilett, tiene usted razón –respondió e...      23
# 4       Grecia tiene muchas islas, con estimaciones qu...     338
# ...                                                   ...     ...
# 109995  No sólo debemos prestar atención a la segurida...      42
# 109996                      No puedo esperar a ser padre.      12
# 109997                    ¿Soy, pues, vuestra prisionera?      15
# 109998  La criosfera (del griego kryos, "frío", "gelad...     348
# 109999  A continuación se presenta una lista de grupos...     343
#
# [110000 rows x 5 columns]

# %%
df = df.sample(frac=1, random_state=seed).reset_index(drop=True)
dfs = [df.iloc[i*10000:(i+1)*10000].reset_index(drop=True) for i in range(8)]
dfs[-1] = df.iloc[70_000:100_000].reset_index(drop=True)  # last chunk may be smaller due to length filtering

# %%
#Init models (make sure you init ONLY once if you integrate this to your code)
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=True)
paraph_df = []
max_paraph_per_sentence = 2
with torch.no_grad():
    for i, row in tqdm.tqdm(dfs[0].iterrows(), total=len(dfs[0])):
        en_phrase = row['EN']
        para_phrases = parrot.augment(input_phrase=en_phrase, 
                                      max_return_phrases=5, 
                                      max_length=row['length'] + 5, 
                                      use_gpu=True)
        if para_phrases is None:
            para_phrases = []
        for k, para_phrase in enumerate(para_phrases):
            new_row = row.to_dict()
            para_phrase = para_phrase[0].strip()
            if para_phrase == en_phrase.strip() or para_phrase == '':
                continue
            new_row['synthetic'] = para_phrase
            new_row['method'] = 'paraphrase'
            new_row['target'] = 'EN'
            paraph_df.append(new_row)
            if k+1 >= max_paraph_per_sentence:
                break
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
#   0%|          | 0/10000 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 100%|██████████| 10000/10000 [55:57<00:00,  2.98it/s]

# %%
paraph_df = pd.DataFrame(paraph_df)
# if EN and EN-Paraphrase are the same, drop the row
paraph_df = paraph_df[paraph_df['EN'] != paraph_df['synthetic']].reset_index(drop=True)
# replace EN with synthetic
paraph_df['EN'] = paraph_df['synthetic']
paraph_df = paraph_df.drop(columns=['synthetic'])
paraph_df
# Out:
#                          dataset  split  \
# 0     english-spanish-translator  train
# 1     english-spanish-translator  train
# 2            wikipedia_en_es_m2m  train
# 3            wikipedia_en_es_m2m  train
# 4          mustc-en-es-text-only  train
# ...                          ...    ...
# 9002       mustc-en-es-text-only  train
# 9003       mustc-en-es-text-only  train
# 9004            OPUS-books-EN-ES  train
# 9005       mustc-en-es-text-only  train
# 9006       mustc-en-es-text-only  train
#
#                                                      EN  \
# 0                              it's awful weather today
# 1                               the weather is horrible
# 2     horsepower hp is a unit of measurement of powe...
# 3     horsepower hp is a unit of measurement of powe...
# 4     coconut shells crushed in a machine mixed with...
# ...                                                 ...
# 9002  we can never go back to a place and find out e...
# 9003  there may be more than three million muslims i...
# 9004            i don't want to hide anything from you'
# 9005  ten days later i'm on call at the san francisc...
# 9006  ten days later i am on call at the san francis...
#
#                                                      ES  length      method  \
# 0                             Hoy hace un clima pésimo.      12  paraphrase
# 1                             Hoy hace un clima pésimo.      12  paraphrase
# 2     La potencia de caballo (hp) es una unidad de m...     349  paraphrase
# 3     La potencia de caballo (hp) es una unidad de m...     349  paraphrase
# 4     Por ejemplo, las cáscaras de coco trituradas e...      76  paraphrase
# ...                                                 ...     ...         ...
# 9002  No podemos volver a un lugar y encontrarlo exa...      26  paraphrase
# 9003     En EE.UU. hay más de 3 millones de musulmanes.      20  paraphrase
# 9004               No puedo ni quiero ocultarle nada...      15  paraphrase
# 9005  Diez días más tarde, estoy de guardia en el Ho...      47  paraphrase
# 9006  Diez días más tarde, estoy de guardia en el Ho...      47  paraphrase
#
#      target
# 0        EN
# 1        EN
# 2        EN
# 3        EN
# 4        EN
# ...     ...
# 9002     EN
# 9003     EN
# 9004     EN
# 9005     EN
# 9006     EN
#
# [9007 rows x 7 columns]

# %%
from transformers import pipeline
import torch
paraphraser_es = pipeline(
    task="text2text-generation",
    model="p-serna/mt5-small-spanish-paraphraser",
    tokenizer="p-serna/mt5-small-spanish-paraphraser",
    device=0 if torch.cuda.is_available() else -1,
)

def generate_spanish_paraphrases(texts, num_return_sequences=3, max_length=128):
    results = {}
    for text in texts:
        outputs = paraphraser_es(
            f"parafrasea: {text}",
            num_return_sequences=num_return_sequences,
            max_new_tokens=max_length,
            clean_up_tokenization_spaces=True,
            truncation=True,
            num_beams=num_return_sequences
        )
        results[text] = [item["generated_text"] for item in outputs]
    return results

spanish_paraphrases = generate_spanish_paraphrases(['¿Puedes recomendar algunos restaurantes exclusivos en Nueva York?',])
spanish_paraphrases
# Out:
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# {'¿Puedes recomendar algunos restaurantes exclusivos en Nueva York?': ['¿Puedes recomendar algunos restaurantes exclusivos en Nueva York?',
#   '¿Cómo puedo recomendar algunos restaurantes exclusivos en Nueva York?',
#   '¿Puedes recomendar algunos restaurantes exclusivos de Nueva York?']}

# %%
spanish_paraph_df = []
max_spanish_paraph_per_sentence = 2

for i, row in tqdm.tqdm(dfs[1].iterrows(), total=len(dfs[1])):
    es_phrase = row["ES"]
    spans = generate_spanish_paraphrases(
        [es_phrase], num_return_sequences=2, max_length=row['length'] + 5
    ).get(es_phrase, [])
    kept = 0
    for span in spans:
        candidate = span.strip()
        if not candidate or candidate == es_phrase.strip():
            continue
        new_row = row.to_dict()
        new_row["synthetic"] = candidate
        new_row["method"] = "spanish_paraphrase"
        new_row['target'] = 'ES'
        spanish_paraph_df.append(new_row)
        kept += 1
        if kept >= max_spanish_paraph_per_sentence:
            break
# Out:
#   0%|          | 9/10000 [00:01<32:14,  5.16it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#  74%|███████▍  | 7401/10000 [55:19<37:51,  1.14it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
spanish_paraph_df = pd.DataFrame(spanish_paraph_df)
spanish_paraph_df = spanish_paraph_df[spanish_paraph_df["ES"] != spanish_paraph_df["synthetic"]].reset_index(drop=True)
# replace ES with synthetic
spanish_paraph_df["ES"] = spanish_paraph_df["synthetic"]
spanish_paraph_df = spanish_paraph_df.drop(columns=["synthetic"])
spanish_paraph_df
# Out:
#                      dataset  split  \
# 0      mustc-en-es-text-only  train
# 1      mustc-en-es-text-only  train
# 2           OPUS-books-EN-ES    val
# 3           OPUS-books-EN-ES    val
# 4           OPUS-books-EN-ES  train
# ...                      ...    ...
# 19113    wikipedia_en_es_m2m  train
# 19114  mustc-en-es-text-only  train
# 19115  mustc-en-es-text-only  train
# 19116  mustc-en-es-text-only  train
# 19117  mustc-en-es-text-only  train
#
#                                                       EN  \
# 0      But, in 2007, Bhumika and Nepal's LGBT rights ...
# 1      But, in 2007, Bhumika and Nepal's LGBT rights ...
# 2         It was the dog of the engineer, Cyrus Harding.
# 3         It was the dog of the engineer, Cyrus Harding.
# 4                               Gideon Spilett was tall.
# ...                                                  ...
# 19113  Year 235 (CCXXXV) was a common year starting o...
# 19114  (Laughter) I looked in the rear-view mirror an...
# 19115  (Laughter) I looked in the rear-view mirror an...
# 19116                               That was the debate.
# 19117                               That was the debate.
#
#                                                       ES  length  \
# 0      Parafrasea: Pero, en 2007, la organización de ...      52
# 1      Pero, en 2007, la organización de derechos LGB...      52
# 2      Parafrasea, era el perro del ingeniero Ciro Sm...      13
# 3      Parafrasea era el perro del ingeniero Ciro Smith.      13
# 4      Parafrasea: Gedón Spillett era alto y tenía un...      21
# ...                                                  ...     ...
# 19113  En ese momento, el año 235 (CCXXXV) fue un año...     304
# 19114  Parafrasea: Sé que suena como cualquier cosa p...      46
# 19115  Parafrasea: Sé que suena como cualquier cosa p...      46
# 19116                     Parafrasea, ese era el debate.       6
# 19117                     Parafrasea: ese era el debate.       6
#
#                    method target
# 0      spanish_paraphrase     ES
# 1      spanish_paraphrase     ES
# 2      spanish_paraphrase     ES
# 3      spanish_paraphrase     ES
# 4      spanish_paraphrase     ES
# ...                   ...    ...
# 19113  spanish_paraphrase     ES
# 19114  spanish_paraphrase     ES
# 19115  spanish_paraphrase     ES
# 19116  spanish_paraphrase     ES
# 19117  spanish_paraphrase     ES
#
# [19118 rows x 7 columns]

# %%
pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")
# Out:
# Device set to use cuda:0

# %%
back_translation_rows = []
batch_size = 32

k = 0
for start in tqdm.tqdm(range(0, len(dfs[2]), batch_size), desc="Back-translation ES→EN"):
    batch = dfs[2].iloc[start:start + batch_size]
    translations = pipe(batch["ES"].tolist())
    for row, translated in zip(batch.to_dict("records"), translations):
        augmented = row.copy()
        augmented["synthetic"] = translated["translation_text"].strip()
        augmented["method"] = "back_translation"
        augmented["target"] = "EN"
        back_translation_rows.append(augmented)
# Out:
# Back-translation ES→EN: 100%|██████████| 313/313 [28:21<00:00,  5.44s/it]

# %%
back_translation_df = pd.DataFrame(back_translation_rows)
back_translation_df = back_translation_df[
    back_translation_df["synthetic"].str.strip().ne(back_translation_df["EN"].str.strip())
].reset_index(drop=True)

# replace EN with synthetic
back_translation_df["EN"] = back_translation_df["synthetic"]
back_translation_df = back_translation_df.drop(columns=["synthetic"])

back_translation_df.head()
# Out:
#                       dataset  split  \
# 0            OPUS-books-EN-ES  train
# 1            OPUS-books-EN-ES    val
# 2  english-spanish-translator  train
# 3            OPUS-books-EN-ES    val
# 4       mustc-en-es-text-only  train
#
#                                                   EN  \
# 0  "Sure!" replied Trifaldin, "that in Candaya, n...
# 1  "Did he ever give any sign of having taken opi...
# 2           You want to leave your bag in the trunk?
# 3  It seemed that the series of supernatural inci...
# 4  Helping my children to be careful, healthy, an...
#
#                                                   ES  length  \
# 0  -¡Claro está! -respondió Trifaldín-, que en Ca...      39
# 1    ––¿Alguna vez dio señales de haber tomado opio?      18
# 2             Quieres dejar tu bolso en el maletero?      14
# 3  Parecía que la serie de incidentes sobrenatura...      89
# 4  Ayudar a mis hijos a ser adultos cuidadosos, s...      34
#
#              method target
# 0  back_translation     EN
# 1  back_translation     EN
# 2  back_translation     EN
# 3  back_translation     EN
# 4  back_translation     EN

# %%
NOISE_CHAR_POOL = (
    list(string.digits + string.punctuation)
    + ["✨", "🔥", "🚀", "💥", "💡", "🌀", "🔒", "🧬", "🌪️", "🧊", "🕶️", "🎯", "⚡", "🛰️", "🤖", "🧨", "💬", "🕳️",
       "¿", "¡", "§", "¶", "©", "™", "Ω", "λ", "Δ", "β", "漢", "字", "零", "龍", "\u200b"]
)


def random_fragment(min_len: int = 4, max_len: int = 16) -> str:
    length = random.randint(min_len, max_len)
    fragment = "".join(random.choice(NOISE_CHAR_POOL) for _ in range(length))
    if random.random() < 0.35:
        fragment = fragment * random.randint(2, 3)
    if random.random() < 0.25:
        fragment = f"{fragment}\n{random_fragment(2, 4)}"
    return fragment


def inject_random_segments(text: str, max_len: int = 4) -> str:
    words = text.split()
    max_len = min(max_len, len(text))
    max_len = min(max_len, len(text)// 3)
    if not words:
        return text
    rand_text = "".join([NOISE_CHAR_POOL[random.randint(0, len(NOISE_CHAR_POOL)-1)] for _ in range(random.randint(1, max_len))])
    # randomly add spaces in the rand_text
    rand_text_ = ""
    for ch in rand_text:
        rand_text_ += ch
        if random.random() < 0.3:
            rand_text_ += " "
    rand_words = rand_text_.strip().split()
    # randomly insert rand_words into words
    insert_positions = sorted(random.sample(range(len(words) + 1), len(rand_words)))
    for offset, (pos, rand_word) in enumerate(zip(insert_positions, rand_words)):
        words.insert(pos + offset, rand_word)
    return " ".join(words)
    


def wrap_words_with_repeated_chars(text: str, wrap_prob: float = 0.35) -> str:
    words = text.split()
    wrapped = []
    for word in words:
        if random.random() < wrap_prob:
            repeated = random.choice(NOISE_CHAR_POOL) * random.randint(1, 4)
            wrapped.append(f"{repeated} {word} {repeated}")
        else:
            wrapped.append(word)
    return " ".join(wrapped)

def randomize_whitespace(text: str, newline_prob: float = 0.3, tab_prob: float = 0.15) -> str:
    buffer = []
    for ch in text:
        if ch == " ":
            roll = random.random()
            if roll < newline_prob:
                buffer.append("\n")
            elif roll < newline_prob + tab_prob:
                buffer.append("\t")
            else:
                buffer.append(" " * random.randint(1, 3))
        else:
            buffer.append(ch)
    return "".join(buffer)


def interleave_noise_lines(text: str, max_lines: int = 3) -> str:
    lines = text.split("\n")
    max_insert = min(max_lines, len(lines) + 1)
    if max_insert == 0:
        return text
    inserts = random.randint(1, max_insert)
    positions = sorted(random.sample(range(len(lines) + 1), inserts))
    for offset, pos in enumerate(positions):
        lines.insert(pos + offset, random_fragment(1, 4))
    return "\n".join(lines)


def apply_adversarial_perturbations(text: str) -> str:
    if not isinstance(text, str) or not text.strip():
        return text
    operations = [
        lambda t: inject_random_segments(t, max_len=20),
        lambda t: wrap_words_with_repeated_chars(t, wrap_prob=0.1),
        lambda t: randomize_whitespace(t, newline_prob=0.1, tab_prob=0.1),
        lambda t: interleave_noise_lines(t, max_lines=2),
    ]
    random.shuffle(operations)
    perturbed = text
    try:
        perturbed = operations[0](perturbed)
    except:
        perturbed = text
    return perturbed


# def adversarialize_english_column(frame, source_col: str = "EN", target_col: str = "EN_adv", apply_prob: float = 0.6):
#     frame[target_col] = frame[source_col].apply(
#         lambda txt: apply_adversarial_perturbations(txt) if isinstance(txt, str) and random.random() < apply_prob else txt
#     )
#     return frame

# apply_adversarial_perturbations("This is a sample case of adversarial perturbation.")

for i, row in tqdm.tqdm(dfs[3].iterrows(), total=len(dfs[3])):
    en_phrase = row['EN']
    augmented_phrase = apply_adversarial_perturbations(en_phrase)
    new_row = row.to_dict()
    new_row['synthetic'] = augmented_phrase
    new_row['method'] = 'adversarial_perturbation'
    new_row['target'] = 'EN'
    dfs[3].at[i, 'synthetic'] = augmented_phrase
    dfs[3].at[i, 'method'] = 'adversarial_perturbation'
    dfs[3].at[i, 'target'] = 'EN'
    
adversarial_df = dfs[3]
# remove if EN and synthetic are the same
adversarial_df = adversarial_df[
    adversarial_df["EN"].str.strip().ne(adversarial_df["synthetic"].str.strip())
].reset_index(drop=True)

# replace EN with synthetic
adversarial_df["EN"] = adversarial_df["synthetic"]
adversarial_df = adversarial_df.drop(columns=["synthetic"])

adversarial_df
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 16846.92it/s]
#                          dataset  split  \
# 0     english-spanish-translator  train
# 1               OPUS-books-EN-ES  train
# 2     english-spanish-translator  train
# 3          mustc-en-es-text-only  train
# 4     english-spanish-translator  train
# ...                          ...    ...
# 9309  english-spanish-translator  train
# 9310         wikipedia_en_es_m2m  train
# 9311       mustc-en-es-text-only  train
# 9312       mustc-en-es-text-only  train
# 9313         wikipedia_en_es_m2m  train
#
#                                                      EN  \
# 0     She drank [ two glasses of wine at the party. 209
# 1     {-+🔥🌪️🕳 "Queer spot to choose, is it not?" sai...
# 2                 ] Do 零🧬 you have any /β brothers? ?0🤖
# 3                         ♫ 🧨©🕶️^✨¶ when black men ski.
# 4                    Tom should 006🧬λ still be at work.
# ...                                                 ...
# 9309      ¿-\n¿3\nDo you have a twin sister?\n7🕳️Ω\n$💥6
# 9310  John Adam Belushi (January 24, 1949 – March 5,...
# 9311  The same adulation of Hitler, praise of the Th...
# 9312  That is 🎯 the change needed to Δ~+龍3🛰 restore ...
# 9313  Alfred Russel Wallace (8 January 18237 Novembe...
#
#                                                      ES  length  \
# 0         Ella se bebió dos vasos de vino en la fiesta.      18
# 1     -Extraña elección para vivir, ¿no es eso? -dij...      41
# 2                                       Tenés hermanos?       6
# 3                  ♫ cuando los hombres negros esquían.      15
# 4              Tom todavía debería estar en el trabajo.      16
# ...                                                 ...     ...
# 9309                         Tienes una hermana gemela?      10
# 9310  John Adam Belushi (24 de enero de 1949 – 5 de ...     308
# 9311  La misma admiración por Hitler, alabanzas al T...      32
# 9312  Ese es el cambio necesario para restaurar el b...      30
# 9313  Alfred Russel Wallace (8 de enero de 18237 de ...     343
#
#                         method target
# 0     adversarial_perturbation     EN
# 1     adversarial_perturbation     EN
# 2     adversarial_perturbation     EN
# 3     adversarial_perturbation     EN
# 4     adversarial_perturbation     EN
# ...                        ...    ...
# 9309  adversarial_perturbation     EN
# 9310  adversarial_perturbation     EN
# 9311  adversarial_perturbation     EN
# 9312  adversarial_perturbation     EN
# 9313  adversarial_perturbation     EN
#
# [9314 rows x 7 columns]

# %%
dfs[3]
# Out:
#                          dataset  split  \
# 0     english-spanish-translator  train
# 1               OPUS-books-EN-ES  train
# 2     english-spanish-translator  train
# 3          mustc-en-es-text-only  train
# 4     english-spanish-translator  train
# ...                          ...    ...
# 9995  english-spanish-translator  train
# 9996         wikipedia_en_es_m2m  train
# 9997       mustc-en-es-text-only  train
# 9998       mustc-en-es-text-only  train
# 9999         wikipedia_en_es_m2m  train
#
#                                                      EN  \
# 0           She drank two glasses of wine at the party.
# 1     "Queer spot to choose, is it not?" said he as ...
# 2                             Do you have any brothers?
# 3                                 ♫ when black men ski.
# 4                          Tom should still be at work.
# ...                                                 ...
# 9995                         Do you have a twin sister?
# 9996  John Adam Belushi (January 24, 1949 – March 5,...
# 9997  The same adulation of Hitler, praise of the Th...
# 9998  That is the change needed to restore energy ba...
# 9999  Alfred Russel Wallace (8 January 18237 Novembe...
#
#                                                      ES  length  \
# 0         Ella se bebió dos vasos de vino en la fiesta.      18
# 1     -Extraña elección para vivir, ¿no es eso? -dij...      41
# 2                                       Tenés hermanos?       6
# 3                  ♫ cuando los hombres negros esquían.      15
# 4              Tom todavía debería estar en el trabajo.      16
# ...                                                 ...     ...
# 9995                         Tienes una hermana gemela?      10
# 9996  John Adam Belushi (24 de enero de 1949 – 5 de ...     308
# 9997  La misma admiración por Hitler, alabanzas al T...      32
# 9998  Ese es el cambio necesario para restaurar el b...      30
# 9999  Alfred Russel Wallace (8 de enero de 18237 de ...     343
#
#                                               synthetic  \
# 0     She drank [ two glasses of wine at the party. 209
# 1     {-+🔥🌪️🕳 "Queer spot to choose, is it not?" sai...
# 2                 ] Do 零🧬 you have any /β brothers? ?0🤖
# 3                         ♫ 🧨©🕶️^✨¶ when black men ski.
# 4                    Tom should 006🧬λ still be at work.
# ...                                                 ...
# 9995      ¿-\n¿3\nDo you have a twin sister?\n7🕳️Ω\n$💥6
# 9996  John Adam Belushi (January 24, 1949 – March 5,...
# 9997  The same adulation of Hitler, praise of the Th...
# 9998  That is 🎯 the change needed to Δ~+龍3🛰 restore ...
# 9999  Alfred Russel Wallace (8 January 18237 Novembe...
#
#                         method target
# 0     adversarial_perturbation     EN
# 1     adversarial_perturbation     EN
# 2     adversarial_perturbation     EN
# 3     adversarial_perturbation     EN
# 4     adversarial_perturbation     EN
# ...                        ...    ...
# 9995  adversarial_perturbation     EN
# 9996  adversarial_perturbation     EN
# 9997  adversarial_perturbation     EN
# 9998  adversarial_perturbation     EN
# 9999  adversarial_perturbation     EN
#
# [10000 rows x 8 columns]

# %%
def swap_adjacent_chars(text: str) -> str:
    if not isinstance(text, str) or len(text) < 2:
        return text
    idx = random.randrange(len(text) - 1)
    chars = list(text)
    chars[idx], chars[idx + 1] = chars[idx + 1], chars[idx]
    return "".join(chars)


def delete_random_char(text: str) -> str:
    if not isinstance(text, str) or not text:
        return text
    idx = random.randrange(len(text))
    return text[:idx] + text[idx + 1:]


def replace_random_char(text: str) -> str:
    if not isinstance(text, str) or not text:
        return text
    idx = random.randrange(len(text))
    replacement_pool = string.ascii_letters + string.digits + string.punctuation
    replacement = random.choice(replacement_pool)
    return text[:idx] + replacement + text[idx + 1:]


def swap_adjacent_words(text: str) -> str:
    words = text.split()
    if len(words) < 2:
        return text
    idx = random.randrange(len(words) - 1)
    words[idx], words[idx + 1] = words[idx + 1], words[idx]
    return " ".join(words)


def delete_random_word(text: str) -> str:
    words = text.split()
    if not words:
        return text
    idx = random.randrange(len(words))
    del words[idx]
    return " ".join(words)


def replace_random_word(text: str) -> str:
    words = text.split()
    if len(words) < 2:
        return text
    idx = random.randrange(len(words))
    replacement = random.choice(words[:idx] + words[idx + 1:])
    words[idx] = replacement
    return " ".join(words)


CHAR_OPS = [swap_adjacent_chars, delete_random_char, replace_random_char]
WORD_OPS = [swap_adjacent_words, delete_random_word, replace_random_word]


def perturb_text(text: str, char_ratio: float = 0.5) -> str:
    if not isinstance(text, str):
        return text
    ops_pool = CHAR_OPS if random.random() < char_ratio else WORD_OPS
    op = random.choice(ops_pool)
    result = op(text)
    return result if result else text


# def augment_with_char_word_ops(frame, source_col="EN", n_samples=5, random_state=None):
#     sampled = frame.sample(n=min(n_samples, len(frame)), random_state=random_state).copy()
#     sampled["synthetic"] = sampled[source_col].apply(lambda txt: perturb_text(txt, char_ratio=0.6))
#     sampled = sampled[sampled["synthetic"].ne(sampled[source_col])]
#     sampled["method"] = "char_word_ops"
#     sampled["target"] = source_col
#     return sampled.reset_index(drop=True)


# char_word_augmented_df = augment_with_char_word_ops(df, source_col="EN", n_samples=20, random_state=seed)
# char_word_augmented_df.head()

# examples
# perturb_text("This is a sample text for perturbation.")
for i, row in tqdm.tqdm(dfs[4].iterrows(), total=len(dfs[4])):
    en_phrase = row['EN']
    augmented_phrase = perturb_text(en_phrase, char_ratio=0.6)
    new_row = row.to_dict()
    new_row['synthetic'] = augmented_phrase
    new_row['method'] = 'char_word_perturbation'
    new_row['target'] = 'EN'
    dfs[4].at[i, 'synthetic'] = augmented_phrase
    dfs[4].at[i, 'method'] = 'char_word_perturbation'
    dfs[4].at[i, 'target'] = 'EN'

dfs[4]
perturbation_df = dfs[4]
# remove if EN and synthetic are the same
perturbation_df = perturbation_df[
    perturbation_df["EN"].str.strip().ne(perturbation_df["synthetic"].str.strip())
].reset_index(drop=True)    
# replace EN with synthetic
perturbation_df["EN"] = perturbation_df["synthetic"]
perturbation_df = perturbation_df.drop(columns=["synthetic"])
perturbation_df
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 20887.88it/s]
#                          dataset  split  \
# 0     Document-Translation-en-es  train
# 1     english-spanish-translator  train
# 2               OPUS-books-EN-ES  train
# 3                   corpus-en-es  train
# 4          mustc-en-es-text-only  train
# ...                          ...    ...
# 9927  english-spanish-translator  train
# 9928            OPUS-books-EN-ES  train
# 9929            OPUS-books-EN-ES  train
# 9930                corpus-en-es  train
# 9931  english-spanish-translator  train
#
#                                                      EN  \
# 0     Liverpool has rejected an offer from Chelsea, ...
# 1                 I'm a thirty-year-ld unmarried woman.
# 2                 But what's of purpose of this refuge?
# 3     This is why the placing of signs with informat...
# 4     The whole business of politics has been effect...
# ...                                                 ...
# 9927  Experience is the name everyone gives to|their...
# 9928  La brute qu’elle avait pour mari, et qui l’ava...
# 9929                          is That very interesting.
# 9930  You have heard words of appreciation, from Mr ...
# 9931                          He gave me back the mony.
#
#                                                      ES  length  \
# 0     El Liverpool ha rechazado una oferta del Chels...     458
# 1                Soy una mujer soltera de treinta años.      16
# 2                          Pero ¿para qué este refugio?      12
# 3     Por eso, la colocación de carteles con informa...      70
# 4     Todo este negocio de la política se ha abandon...      43
# ...                                                 ...     ...
# 9927  Experiencia es el nombre que todo el mundo le ...      21
# 9928  Su estúpido marido, que la había desposado sob...      96
# 9929                            Eso es muy interesante.      10
# 9930  Ha escuchado usted palabras de agradecimiento,...      90
# 9931                             Me devolvió el dinero.       9
#
#                       method target
# 0     char_word_perturbation     EN
# 1     char_word_perturbation     EN
# 2     char_word_perturbation     EN
# 3     char_word_perturbation     EN
# 4     char_word_perturbation     EN
# ...                      ...    ...
# 9927  char_word_perturbation     EN
# 9928  char_word_perturbation     EN
# 9929  char_word_perturbation     EN
# 9930  char_word_perturbation     EN
# 9931  char_word_perturbation     EN
#
# [9932 rows x 7 columns]

# %%
import nltk
from nltk.corpus import wordnet as wn

nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)

def synonym_replacement(sentence, max_replacements=2):
    words = sentence.split()
    replaceable = [i for i, w in enumerate(words) if wn.synsets(w)]
    random.shuffle(replaceable)
    replaced = 0
    for idx in replaceable:
        syns = wn.synsets(words[idx])
        lemmas = {lemma.replace("_", " ") for syn in syns for lemma in syn.lemma_names()}
        lemmas.discard(words[idx])
        if not lemmas:
            continue
        words[idx] = random.choice(list(lemmas))
        replaced += 1
        if replaced >= max_replacements:
            break
    return " ".join(words)

english_synonym_rows = []
for i, row in tqdm.tqdm(dfs[5].iterrows(), total=len(dfs[5]), desc="EN synonym replacement"):
    original = row["EN"]
    augmented = synonym_replacement(original)
    if augmented.strip() == original.strip():
        continue
    new_row = row.to_dict()
    new_row["synthetic"] = augmented
    new_row["method"] = "english_synonym"
    new_row["target"] = "EN"
    english_synonym_rows.append(new_row)

english_synonym_df = pd.DataFrame(english_synonym_rows)
# remove if EN and synthetic are the same
english_synonym_df = english_synonym_df[
    english_synonym_df["EN"].str.strip().ne(english_synonym_df["synthetic"].str.strip())
].reset_index(drop=True)
# replace EN with synthetic
english_synonym_df["EN"] = english_synonym_df["synthetic"]
english_synonym_df = english_synonym_df.drop(columns=["synthetic"])
english_synonym_df.head()
# Out:
# EN synonym replacement: 100%|██████████| 10000/10000 [00:07<00:00, 1273.52it/s]
#                  dataset  split  \
# 0       OPUS-books-EN-ES  train
# 1       OPUS-books-EN-ES  train
# 2    wikipedia_en_es_m2m  train
# 3       OPUS-books-EN-ES  train
# 4  mustc-en-es-text-only  train
#
#                                                   EN  \
# 0  This post was one of those, now far more numer...
# 1                            Have they non obey me?"
# 2  In mathematics, a complete measure (or, more p...
# 3   "Silence!" exclaim Felton; "we constitute here."
# 4  It's the same principle: it's got O on one sid...
#
#                                                   ES  length           method  \
# 0  Entonces decidió escuchar, observar, orientars...      69  english_synonym
# 1                            ¿No se me ha obedecido?      10  english_synonym
# 2  En matemáticas, una medida completa (o, más pr...     331  english_synonym
# 3            ¡Silencio! dijo Felton . Hemos llegado.      17  english_synonym
# 4  Sigue el mismo principio: toma el oxígeno por ...      58  english_synonym
#
#   target
# 0     EN
# 1     EN
# 2     EN
# 3     EN
# 4     EN

# %%
def spanish_synonym_replacement(sentence, max_replacements=2):
    words = sentence.split()
    replaceable = [i for i, w in enumerate(words) if wn.synsets(w, lang="spa")]
    random.shuffle(replaceable)
    replaced = 0
    for idx in replaceable:
        syns = wn.synsets(words[idx], lang="spa")
        lemmas = {
            lemma.replace("_", " ")
            for syn in syns
            for lemma in syn.lemma_names(lang="spa")
        }
        lemmas.discard(words[idx])
        if not lemmas:
            continue
        words[idx] = random.choice(list(lemmas))
        replaced += 1
        if replaced >= max_replacements:
            break
    return " ".join(words)

spanish_synonym_rows = []
for i, row in tqdm.tqdm(dfs[6].iterrows(), total=len(dfs[6]), desc="ES synonym replacement"):
    original = row["ES"]
    augmented = spanish_synonym_replacement(original)
    if augmented.strip() == original.strip():
        continue
    new_row = row.to_dict()
    new_row["synthetic"] = augmented
    new_row["method"] = "spanish_synonym"
    new_row["target"] = "ES"
    spanish_synonym_rows.append(new_row)

spanish_synonym_df = pd.DataFrame(spanish_synonym_rows)
spanish_synonym_df = spanish_synonym_df[
    spanish_synonym_df["ES"].str.strip().ne(spanish_synonym_df["synthetic"].str.strip())
].reset_index(drop=True)
# replace ES with synthetic
spanish_synonym_df["ES"] = spanish_synonym_df["synthetic"]
spanish_synonym_df = spanish_synonym_df.drop(columns=["synthetic"])

spanish_synonym_df.head()
# Out:
# ES synonym replacement: 100%|██████████| 10000/10000 [00:01<00:00, 8835.17it/s]
#                  dataset  split  \
# 0       OPUS-books-EN-ES  train
# 1  mustc-en-es-text-only  train
# 2  mustc-en-es-text-only  train
# 3       OPUS-books-EN-ES  train
# 4    wikipedia_en_es_m2m  train
#
#                                                   EN  \
# 0  No one, at least, can think I have not done en...
# 1  What has also happened is in the course of the...
# 2  Here's what I've learned from studying shocks ...
# 3  'How pleased I am to see you!' said Vronsky, a...
# 4  The Grand Union Canal in England is part of th...
#
#                                                   ES  length           method  \
# 0  Al menos, nadie puede cogitación que no he hec...      49  spanish_synonym
# 1  Lo que además ha sucedido durante estos viajes...      57  spanish_synonym
# 2  Esto he aprendido estudiando crisis y desastre...      48  spanish_synonym
# 3  –¡Cuánto celebro verte! –dijo Vronsky, mostran...      45  spanish_synonym
# 4  El Canal de la Gran Unión en Inglaterra es par...     332  spanish_synonym
#
#   target
# 0     ES
# 1     ES
# 2     ES
# 3     ES
# 4     ES

# %%
# concatenate two random english phrases and output their spanish translation
def proc(row1, row2):
    if random.random() < 0.5:
        en = f"{row1['EN']} {row2['EN']}"
        es = f"{row1['ES']} {row2['ES']}"
    else:
        en = f"{row2['EN']} {row1['EN']}"
        es = f"{row2['ES']} {row1['ES']}"
    return pd.Series({"EN": en, "ES": es, "split": row1["split"], 'dataset': 'mixed'})

concat_rows = []
for i in tqdm.tqdm(range(len(dfs[7])), desc="Concatenate EN-ES pairs"):
    row1 = dfs[7].iloc[i]
    j = random.randint(0, len(dfs[7]) - 1)
    while j == i or dfs[7].iloc[j]["split"] != row1["split"]:
        j = random.randint(0, len(dfs[7]) - 1)
    row2 = dfs[7].iloc[j]
    new_row = proc(row1, row2).to_dict()
    new_row.update({
        'method': 'concatenate',
        'target': 'BOTH'
    })
    concat_rows.append(new_row)

concat_df = pd.DataFrame(concat_rows)
concat_df.head()
# Out:
# Concatenate EN-ES pairs: 100%|██████████| 30000/30000 [00:03<00:00, 8920.30it/s]
#                                                   EN  \
# 0  What time is your plane scheduled to take off?...
# 1  Hand me the wrench. It was lit only by the dim...
# 2  Burnham had designed a railroad station that w...
# 3  Now, I'm not here to tell you what kind of leg...
# 4  Cet assassin inconnu procédait d’une façon si ...
#
#                                                   ES  split dataset  \
# 0  A qué hora sale tu avión? Entonces qué hacemos...  train   mixed
# 1  Pásame la llave. Iluminado solo por el tenue r...  train   mixed
# 2  Burnham había diseñado una estación de trenes ...  train   mixed
# 3  No estoy aquí para decirles qué leyes deberían...    val   mixed
# 4  Había un no sé qué de metódico e incomprensibl...  train   mixed
#
#         method target
# 0  concatenate   BOTH
# 1  concatenate   BOTH
# 2  concatenate   BOTH
# 3  concatenate   BOTH
# 4  concatenate   BOTH

# %%
# collect all synthetic dataframes
synthetic_dfs = [
    paraph_df,
    spanish_paraph_df,
    back_translation_df,
    adversarial_df,
    perturbation_df,
    english_synonym_df,
    spanish_synonym_df,
    concat_df,
]
synthetic_df = pd.concat(synthetic_dfs).reset_index(drop=True)

# %%
synthetic_df
# Out:
#                            dataset  split  \
# 0       english-spanish-translator  train
# 1       english-spanish-translator  train
# 2              wikipedia_en_es_m2m  train
# 3              wikipedia_en_es_m2m  train
# 4            mustc-en-es-text-only  train
# ...                            ...    ...
# 104975                       mixed  train
# 104976                       mixed  train
# 104977                       mixed  train
# 104978                       mixed  train
# 104979                       mixed  train
#
#                                                        EN  \
# 0                                it's awful weather today
# 1                                 the weather is horrible
# 2       horsepower hp is a unit of measurement of powe...
# 3       horsepower hp is a unit of measurement of powe...
# 4       coconut shells crushed in a machine mixed with...
# ...                                                   ...
# 104975  My hedge was begun and carried on, I believe, ...
# 104976             I hate lawyers. Do you like pork loin?
# 104977  Gluten is a structural protein naturally found...
# 104978  I should like to emphasise that there is no ro...
# 104979  The Boeing CIM-10 BOMARC (Boeing Michigan Aero...
#
#                                                        ES  length  \
# 0                               Hoy hace un clima pésimo.    12.0
# 1                               Hoy hace un clima pésimo.    12.0
# 2       La potencia de caballo (hp) es una unidad de m...   349.0
# 3       La potencia de caballo (hp) es una unidad de m...   349.0
# 4       Por ejemplo, las cáscaras de coco trituradas e...    76.0
# ...                                                   ...     ...
# 104975  Interrumpí las labores de inmediato y, para em...     NaN
# 104976    Odio a los abogados. Le gusta el lomo de cerdo?     NaN
# 104977  El gluten es una proteína estructural que se e...     NaN
# 104978  Me gustaría resaltar que en este tema no hay l...     NaN
# 104979  El Boeing CIM-10 BOMARC (Boeing Michigan Aeron...     NaN
#
#              method target
# 0        paraphrase     EN
# 1        paraphrase     EN
# 2        paraphrase     EN
# 3        paraphrase     EN
# 4        paraphrase     EN
# ...             ...    ...
# 104975  concatenate   BOTH
# 104976  concatenate   BOTH
# 104977  concatenate   BOTH
# 104978  concatenate   BOTH
# 104979  concatenate   BOTH
#
# [104980 rows x 7 columns]

# %%
synthetic_df['method'].unique()
# Out:
# array(['paraphrase', 'spanish_paraphrase', 'back_translation',
#        'adversarial_perturbation', 'char_word_perturbation',
#        'english_synonym', 'spanish_synonym', 'concatenate'], dtype=object)

# %%
synthetic_df['method'].value_counts()
# Out:
# method
# concatenate                 30000
# spanish_paraphrase          19118
# char_word_perturbation       9932
# english_synonym              9818
# adversarial_perturbation     9314
# paraphrase                   9007
# spanish_synonym              8903
# back_translation             8888
# Name: count, dtype: int64

# %%
# pip install transformers
from transformers import AutoModelForCausalLM, AutoTokenizer
checkpoint = "HuggingFaceTB/SmolLM-135M"
device = "cuda" # for GPU usage or "cpu" for CPU usage
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
target_column_map = {"EN": "EN", "ES": "ES", "BOTH": "EN"}

dedup_groups = []
for (dataset_name, target_name), group in synthetic_df.groupby(["dataset", "target"], dropna=False):
    subset_col = target_column_map.get(target_name, "EN")
    dedup_groups.append(group.drop_duplicates(subset=subset_col).reset_index(drop=True))

xsynthetic_df = pd.concat(dedup_groups, ignore_index=True)

# %%
xsynthetic_df['method'].value_counts()
# Out:
# method
# concatenate                 30000
# spanish_paraphrase          19065
# char_word_perturbation       9932
# english_synonym              9818
# adversarial_perturbation     9314
# paraphrase                   8991
# spanish_synonym              8902
# back_translation             8883
# Name: count, dtype: int64

# %%
xsynthetic_df
# Out:
#                            dataset  split  \
# 0       Document-Translation-en-es  train
# 1       Document-Translation-en-es  train
# 2       Document-Translation-en-es  train
# 3       Document-Translation-en-es  train
# 4       Document-Translation-en-es  train
# ...                            ...    ...
# 104900         wikipedia_en_es_m2m  train
# 104901         wikipedia_en_es_m2m  train
# 104902         wikipedia_en_es_m2m    val
# 104903         wikipedia_en_es_m2m  train
# 104904         wikipedia_en_es_m2m  train
#
#                                                        EN  \
# 0       german midfielder daniel bierofka suffered a f...
# 1       the german midfielder daniel bierofka suffered...
# 2       at a time of maximum tension between the gener...
# 3       listen to it on your phone if you have an ipho...
# 4       the recent events have again shown that realit...
# ...                                                   ...
# 104900  Smallfilms is a British television production ...
# 104901  A raster image processor (RIP) is a component ...
# 104902  Events Pre-1600 1568 – The Spanish Duke of Alb...
# 104903  z/OS is a 64-bit operating system for IBM z/Ar...
# 104904  These are lists of animated television series....
#
#                                                        ES  length  \
# 0       El centrocampista alemán Daniel Bierofka sufri...   294.0
# 1       El centrocampista alemán Daniel Bierofka sufri...   294.0
# 2       En un momento de máxima tensión entre la Gener...   477.0
# 3       Escúchalo en tu móvi   . Si tienes un iPhone o...   289.0
# 4       Los recientes acontecimientos han demostrado (...   271.0
# ...                                                   ...     ...
# 104900  Smallfilms es una compañía de producción de te...   370.0
# 104901  Un procesador de imagen de raster (RIP) es un ...   359.0
# 104902  Eventos Pre-1600 1568 – El duque español de Al...   346.0
# 104903  z/OS es un sistema operativo de 64 bits para I...   303.0
# 104904  Estas son listas de series de televisión anima...   399.0
#
#                  method target
# 0            paraphrase     EN
# 1            paraphrase     EN
# 2            paraphrase     EN
# 3            paraphrase     EN
# 4            paraphrase     EN
# ...                 ...    ...
# 104900  spanish_synonym     ES
# 104901  spanish_synonym     ES
# 104902  spanish_synonym     ES
# 104903  spanish_synonym     ES
# 104904  spanish_synonym     ES
#
# [104905 rows x 7 columns]

# %%
# apply length
template = "English: {english} Spanish: {spanish} <|END|>"
xsynthetic_df['length'] = xsynthetic_df.apply(
    lambda row: len(tokenizer.encode(
        template.format(english=row['EN'], spanish=row['ES']),
        return_tensors="pt",
    )[0]),
    axis=1
)

# %%
xsynthetic_df = xsynthetic_df[xsynthetic_df['length'] <= 512].reset_index(drop=True)

# %%
# number of samples per method
xsynthetic_df['method'].value_counts()
# Out:
# method
# concatenate                 21887
# spanish_paraphrase          17583
# paraphrase                   8980
# char_word_perturbation       8606
# english_synonym              8473
# back_translation             7867
# adversarial_perturbation     7838
# spanish_synonym              7560
# Name: count, dtype: int64

# %%
# max sample per method
max_samples_per_method = 10_000
balanced_dfs = []
for method, group in xsynthetic_df.groupby('method'):
    if len(group) > max_samples_per_method:
        balanced_dfs.append(
            group.sample(n=max_samples_per_method, random_state=seed).reset_index(drop=True)
        )
    else:
        balanced_dfs.append(group.reset_index(drop=True))
balanced_synthetic_df = pd.concat(balanced_dfs).reset_index(drop=True)
balanced_synthetic_df['method'].value_counts()
# Out:
# method
# concatenate                 10000
# spanish_paraphrase          10000
# paraphrase                   8980
# char_word_perturbation       8606
# english_synonym              8473
# back_translation             7867
# adversarial_perturbation     7838
# spanish_synonym              7560
# Name: count, dtype: int64

# %%
balanced_synthetic_df
# Out:
#                           dataset  split  \
# 0      Document-Translation-en-es  train
# 1      Document-Translation-en-es  train
# 2      Document-Translation-en-es  train
# 3      Document-Translation-en-es    val
# 4      Document-Translation-en-es  train
# ...                           ...    ...
# 69319         wikipedia_en_es_m2m  train
# 69320         wikipedia_en_es_m2m  train
# 69321         wikipedia_en_es_m2m  train
# 69322         wikipedia_en_es_m2m  train
# 69323         wikipedia_en_es_m2m  train
#
#                                                       EN  \
# 0      4¶\n*漢\n5|龍字\n27 people, aged between 16 and 7...
# 1      Tidying  up  your  house\nhad   never\tbeen so...
# 2      =⚡龍\nFifty-three people with arrest warrants w...
# 3      Two  deer\tspecimens from the   Citadel   pack...
# 4      The\nWho   will   give  a memorable concert fo...
# ...                                                  ...
# 69319  In chemistry and atomic physics, the main grou...
# 69320  A Dungeon Master is the organizer of a Dungeon...
# 69321  Total war is warfare that includes any and all...
# 69322  In telecommunications, asynchronous operation ...
# 69323  Tunisia, officially the Republic of Tunisia, i...
#
#                                                       ES  length  \
# 0      27 personas, de entre 16 y 79 años, resultaron...     377
# 1      Ordenar tu casa nunca había tenido tanta impor...     505
# 2      Cincuenta y tres personas con órdenes de captu...     448
# 3      Dos ejemplares de ciervos de la manada de la C...     511
# 4      The Who dará un conmemorable concierto para to...     407
# ...                                                  ...     ...
# 69319  En química y física atómica, el grupo principa...     505
# 69320  Dungeon Master además puede referirse a: Gamin...     484
# 69321  La guerra total es la guerra que incluye todos...     511
# 69322  En telecomunicaciones, operación asíncrona o o...     271
# 69323  Túnez, oficialmente la República de Túnez, es ...     482
#
#                          method target
# 0      adversarial_perturbation     EN
# 1      adversarial_perturbation     EN
# 2      adversarial_perturbation     EN
# 3      adversarial_perturbation     EN
# 4      adversarial_perturbation     EN
# ...                         ...    ...
# 69319           spanish_synonym     ES
# 69320           spanish_synonym     ES
# 69321           spanish_synonym     ES
# 69322           spanish_synonym     ES
# 69323           spanish_synonym     ES
#
# [69324 rows x 7 columns]

# %%
null_summary = df.isnull().any()
print(null_summary)
print(f"Any column contains nulls: {null_summary.any()}")
# Out:
# dataset    False
# split      False
# EN         False
# ES         False
# length     False
# dtype: bool
# Any column contains nulls: False

# %%
balanced_synthetic_df.to_parquet("exp-data/synthetic-en-es-data.parquet", index=False)

# %%
import pandas as pd
aug_df = pd.read_parquet("exp-data/synthetic-en-es-data.parquet")

# %%
aug_df
# Out:
#                           dataset  split  \
# 0      Document-Translation-en-es  train
# 1      Document-Translation-en-es  train
# 2      Document-Translation-en-es  train
# 3      Document-Translation-en-es    val
# 4      Document-Translation-en-es  train
# ...                           ...    ...
# 69319         wikipedia_en_es_m2m  train
# 69320         wikipedia_en_es_m2m  train
# 69321         wikipedia_en_es_m2m  train
# 69322         wikipedia_en_es_m2m  train
# 69323         wikipedia_en_es_m2m  train
#
#                                                       EN  \
# 0      4¶\n*漢\n5|龍字\n27 people, aged between 16 and 7...
# 1      Tidying  up  your  house\nhad   never\tbeen so...
# 2      =⚡龍\nFifty-three people with arrest warrants w...
# 3      Two  deer\tspecimens from the   Citadel   pack...
# 4      The\nWho   will   give  a memorable concert fo...
# ...                                                  ...
# 69319  In chemistry and atomic physics, the main grou...
# 69320  A Dungeon Master is the organizer of a Dungeon...
# 69321  Total war is warfare that includes any and all...
# 69322  In telecommunications, asynchronous operation ...
# 69323  Tunisia, officially the Republic of Tunisia, i...
#
#                                                       ES  length  \
# 0      27 personas, de entre 16 y 79 años, resultaron...     377
# 1      Ordenar tu casa nunca había tenido tanta impor...     505
# 2      Cincuenta y tres personas con órdenes de captu...     448
# 3      Dos ejemplares de ciervos de la manada de la C...     511
# 4      The Who dará un conmemorable concierto para to...     407
# ...                                                  ...     ...
# 69319  En química y física atómica, el grupo principa...     505
# 69320  Dungeon Master además puede referirse a: Gamin...     484
# 69321  La guerra total es la guerra que incluye todos...     511
# 69322  En telecomunicaciones, operación asíncrona o o...     271
# 69323  Túnez, oficialmente la República de Túnez, es ...     482
#
#                          method target
# 0      adversarial_perturbation     EN
# 1      adversarial_perturbation     EN
# 2      adversarial_perturbation     EN
# 3      adversarial_perturbation     EN
# 4      adversarial_perturbation     EN
# ...                         ...    ...
# 69319           spanish_synonym     ES
# 69320           spanish_synonym     ES
# 69321           spanish_synonym     ES
# 69322           spanish_synonym     ES
# 69323           spanish_synonym     ES
#
# [69324 rows x 7 columns]

# %%
aug_df['split'].value_counts(normalize=True)
# Out:
# split
# train    0.908733
# val      0.091267
# Name: proportion, dtype: float64

# %%
train_proc_df = pd.read_parquet("exp-data/en-es-train-val.parquet")

# %%
train_proc_df
# Out:
#                            dataset  split  \
# 0       english-spanish-translator  train
# 1       english-spanish-translator  train
# 2       english-spanish-translator  train
# 3            mustc-en-es-text-only  train
# 4            mustc-en-es-text-only  train
# ...                            ...    ...
# 109995  english-spanish-translator    val
# 109996       mustc-en-es-text-only    val
# 109997  english-spanish-translator    val
# 109998       mustc-en-es-text-only    val
# 109999            OPUS-books-EN-ES    val
#
#                                                        EN  \
# 0                     I heard it thunder in the distance.
# 1                    The divers were trapped in the cave.
# 2                 He told me that he was very tired then.
# 3       From a governmental perspective, from a social...
# 4       But there's a problem with this, and that is, ...
# ...                                                   ...
# 109995                             Stand up for yourself.
# 109996  I pause and I think, how could all of this go ...
# 109997                    I guarantee I'll get you a job.
# 109998  And I think computers today are doing quite th...
# 109999  D’Artagnan perceived that it would be disoblig...
#
#                                                        ES  length
# 0                          Escuché truenos en la lejanía.      28
# 1             Los buzos quedaron atrapados en la caverna.      32
# 2       Él me dijo que estaba muy cansado en ese momento.      37
# 3       Aspiramos a que todos tengan acceso a la energ...      68
# 4       Pero hay un problema con esto, y es que los se...     100
# ...                                                   ...     ...
# 109995                            Levántate por ti mismo.      23
# 109996  Me detengo y pienso, ¿cómo podría todo esto te...      80
# 109997            Te aseguro que te conseguiré un empleo.      34
# 109998  Y creo que las computadoras de hoy están hacie...      42
# 109999  D'Artagnan comprendió que sería contrariar a A...     111
#
# [110000 rows x 5 columns]
